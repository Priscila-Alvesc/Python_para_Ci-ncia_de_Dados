# %% [markdown]
# #### Importação das Bibliotecas

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\virtualenvs\pucminas\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\virtualenvs\pucminas\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\virtualenvs\pucminas\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\virtualenvs\pucminas\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in c:\virtualenvs\pucminas\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\virtualenvs\pucminas\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\virtualenvs\pucminas\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\virtualenvs\pucminas\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\virtualenvs\pucminas\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\virtualenvs\pucminas\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('./datasets/vendas_regiao.csv' ,sep=',', encoding='latin1')
df.head()
# Out:
#    ID_Cliente              Nome_Cliente  id_estado sigla    estado    regiao  \
# 0           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 1           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 2           2    Srta. Kamilly da Rocha          4    AM  Amazonas     Norte
# 3           3             Amanda Farias         10    MA  Maranhão  Nordeste
# 4           3             Amanda Farias         10    MA  Maranhão  Nordeste
#
#    ID_Venda        Data SKU_Produto    Categoria            Nome_Produto  \
# 0        33  2023-05-18   SKU-53822   Brinquedos           Quebra-cabeça
# 1       844  2023-03-30   SKU-97371      Esporte                  Patins
# 2       931  2023-12-28   SKU-50582  Eletrônicos                  Laptop
# 3        82  2023-11-22   SKU-97371      Esporte                  Patins
# 4       373  2023-01-14   SKU-69331         Casa  Organizador de Gavetas
#
#    Quantidade    Preco  valor_venda        Canal
# 0          10   122.47      1224.70  Loja Física
# 1           3   237.06       711.18  Loja Física
# 2           5  4526.60     22633.00       Online
# 3           8   237.06      1896.48       Online
# 4           3   136.47       409.41       Online

# %% [markdown]
# #### Gráfico de Barras
# ***
# Um gráfico de barras é uma representação visual que usa barras retangulares para mostrar e comparar valores entre diferentes categorias. Cada barra representa uma categoria e seu tamanho é proporcional ao valor que representa. Esse tipo de gráfico é útil para visualizar e comparar dados de forma clara, sendo amplamente utilizado em relatórios, pesquisas e análises estatísticas.

# %%
#vendo dados vendas por regiçao pela soma total 
vendas_regiao_soma = df.groupby(['regiao', 'Canal'])['valor_venda'].sum().reset_index()
vendas_regiao_soma.sort_values(by='valor_venda', inplace=True, ascending=False)
vendas_regiao_soma
# Out:
#          regiao        Canal  valor_venda
# 3      Nordeste       Online    758777.45
# 4         Norte  Loja Física    583467.33
# 2      Nordeste  Loja Física    559776.56
# 5         Norte       Online    430254.68
# 1  Centro-Oeste       Online    318851.53
# 9           Sul       Online    233708.81
# 6       Sudeste  Loja Física    228608.08
# 8           Sul  Loja Física    221261.09
# 0  Centro-Oeste  Loja Física    135031.15
# 7       Sudeste       Online    115019.85

# %%
sns.barplot(data= vendas_regiao_soma, 
            x ='regiao',
            y = 'valor_venda',
            hue= 'Canal')
# Out:
# <Axes: xlabel='regiao', ylabel='valor_venda'>

# %%
#Vendo dados pela media das vendas por cancal de venda
vendas_regiao_media = df.groupby(['regiao', 'Canal'])['valor_venda'].mean().reset_index()
vendas_regiao_media.sort_values(by='valor_venda', inplace=True, ascending=False)
vendas_regiao_media
# Out:
#          regiao        Canal  valor_venda
# 9           Sul       Online  4582.525686
# 8           Sul  Loja Física  4338.452745
# 2      Nordeste  Loja Física  4177.437015
# 4         Norte  Loja Física  3646.670812
# 6       Sudeste  Loja Física  3628.699683
# 3      Nordeste       Online  3613.225952
# 1  Centro-Oeste       Online  3503.862967
# 5         Norte       Online  3073.247714
# 0  Centro-Oeste  Loja Física  2700.623000
# 7       Sudeste       Online  2300.397000

# %%
sns.barplot(data= vendas_regiao_media, 
            x ='regiao',
            y = 'valor_venda',
            hue= 'Canal')
# Out:
# <Axes: xlabel='regiao', ylabel='valor_venda'>

# %%
#Customizando o grafico
plt.figure(figsize= (12, 8))
sns.set_palette('Pastel1')
sns.barplot(data= vendas_regiao_media
            x ='regiao',
            y = 'valor_venda',
            hue= 'Canal')
plt.title('Distribuição de vendas por Região')
plt.ylabel('Valor Agregado')
plt.xlabel('Regiao Analisada')
plt.show()
# Out:
#   Cell In[10], line 4
#     sns.barplot(data= vendas_regiao_media
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# #### Gráfico de Linhas
# ***
# Um gráfico de linhas é uma representação visual de dados onde pontos de dados são conectados por linhas para mostrar mudanças ao longo de um eixo, geralmente o tempo. Cada ponto representa um valor específico em um determinado momento. Esse tipo de gráfico é ideal para visualizar tendências, variações e padrões ao longo do tempo, como crescimento de vendas, evolução de preços ou mudanças em medidas científicas. É amplamente utilizado em análise de dados financeiros, estudos de mercado e pesquisa científica para facilitar a interpretação de dados sequenciais.

# %%
df.head()
# Out:
#    ID_Cliente              Nome_Cliente  id_estado sigla    estado    regiao  \
# 0           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 1           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 2           2    Srta. Kamilly da Rocha          4    AM  Amazonas     Norte
# 3           3             Amanda Farias         10    MA  Maranhão  Nordeste
# 4           3             Amanda Farias         10    MA  Maranhão  Nordeste
#
#    ID_Venda        Data SKU_Produto    Categoria            Nome_Produto  \
# 0        33  2023-05-18   SKU-53822   Brinquedos           Quebra-cabeça
# 1       844  2023-03-30   SKU-97371      Esporte                  Patins
# 2       931  2023-12-28   SKU-50582  Eletrônicos                  Laptop
# 3        82  2023-11-22   SKU-97371      Esporte                  Patins
# 4       373  2023-01-14   SKU-69331         Casa  Organizador de Gavetas
#
#    Quantidade    Preco  valor_venda        Canal
# 0          10   122.47      1224.70  Loja Física
# 1           3   237.06       711.18  Loja Física
# 2           5  4526.60     22633.00       Online
# 3           8   237.06      1896.48       Online
# 4           3   136.47       409.41       Online

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Cliente    1000 non-null   int64
#  1   Nome_Cliente  1000 non-null   object
#  2   id_estado     1000 non-null   int64
#  3   sigla         1000 non-null   object
#  4   estado        1000 non-null   object
#  5   regiao        1000 non-null   object
#  6   ID_Venda      1000 non-null   int64
#  7   Data          1000 non-null   object
#  8   SKU_Produto   1000 non-null   object
#  9   Categoria     1000 non-null   object
#  10  Nome_Produto  1000 non-null   object
#  11  Quantidade    1000 non-null   int64
#  12  Preco         1000 non-null   float64
#  13  valor_venda   1000 non-null   float64
#  14  Canal         1000 non-null   object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 117.3+ KB

# %%
#Tratamento de dados do campo DATA
pd.to_datetime(df['Data'])
# Out:
# 0     2023-05-18
# 1     2023-03-30
# 2     2023-12-28
# 3     2023-11-22
# 4     2023-01-14
#          ...
# 995   2023-03-07
# 996   2023-09-01
# 997   2023-12-30
# 998   2023-06-13
# 999   2023-11-24
# Name: Data, Length: 1000, dtype: datetime64[ns]

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Cliente    1000 non-null   int64
#  1   Nome_Cliente  1000 non-null   object
#  2   id_estado     1000 non-null   int64
#  3   sigla         1000 non-null   object
#  4   estado        1000 non-null   object
#  5   regiao        1000 non-null   object
#  6   ID_Venda      1000 non-null   int64
#  7   Data          1000 non-null   datetime64[ns]
#  8   SKU_Produto   1000 non-null   object
#  9   Categoria     1000 non-null   object
#  10  Nome_Produto  1000 non-null   object
#  11  Quantidade    1000 non-null   int64
#  12  Preco         1000 non-null   float64
#  13  valor_venda   1000 non-null   float64
#  14  Canal         1000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 117.3+ KB

# %%
df['Data'] = pd.to_datetime(df['Data'])
df['mes'] = df['Data'].dt.month

# %%
df.head()
# Out:
#    ID_Cliente              Nome_Cliente  id_estado sigla    estado    regiao  \
# 0           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 1           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 2           2    Srta. Kamilly da Rocha          4    AM  Amazonas     Norte
# 3           3             Amanda Farias         10    MA  Maranhão  Nordeste
# 4           3             Amanda Farias         10    MA  Maranhão  Nordeste
#
#    ID_Venda       Data SKU_Produto    Categoria            Nome_Produto  \
# 0        33 2023-05-18   SKU-53822   Brinquedos           Quebra-cabeça
# 1       844 2023-03-30   SKU-97371      Esporte                  Patins
# 2       931 2023-12-28   SKU-50582  Eletrônicos                  Laptop
# 3        82 2023-11-22   SKU-97371      Esporte                  Patins
# 4       373 2023-01-14   SKU-69331         Casa  Organizador de Gavetas
#
#    Quantidade    Preco  valor_venda        Canal  mes data_mes
# 0          10   122.47      1224.70  Loja Física    5  2023-05
# 1           3   237.06       711.18  Loja Física    3  2023-03
# 2           5  4526.60     22633.00       Online   12  2023-12
# 3           8   237.06      1896.48       Online   11  2023-11
# 4           3   136.47       409.41       Online    1  2023-01

# %%
df['Data'] = pd.to_datetime(df['Data'])
df['mes'] = df['Data'].dt.month
df['data_mes'] = df['Data'] .dt.to_period('M')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Cliente    1000 non-null   int64
#  1   Nome_Cliente  1000 non-null   object
#  2   id_estado     1000 non-null   int64
#  3   sigla         1000 non-null   object
#  4   estado        1000 non-null   object
#  5   regiao        1000 non-null   object
#  6   ID_Venda      1000 non-null   int64
#  7   Data          1000 non-null   datetime64[ns]
#  8   SKU_Produto   1000 non-null   object
#  9   Categoria     1000 non-null   object
#  10  Nome_Produto  1000 non-null   object
#  11  Quantidade    1000 non-null   int64
#  12  Preco         1000 non-null   float64
#  13  valor_venda   1000 non-null   float64
#  14  Canal         1000 non-null   object
#  15  mes           1000 non-null   int32
#  16  data_mes      1000 non-null   period[M]
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(4), object(8), period[M](1)
# memory usage: 129.0+ KB

# %%
df.head()
# Out:
#    ID_Cliente              Nome_Cliente  id_estado sigla    estado    regiao  \
# 0           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 1           1  Sr. Enzo Gabriel Azevedo         22    RO  Rondônia     Norte
# 2           2    Srta. Kamilly da Rocha          4    AM  Amazonas     Norte
# 3           3             Amanda Farias         10    MA  Maranhão  Nordeste
# 4           3             Amanda Farias         10    MA  Maranhão  Nordeste
#
#    ID_Venda       Data SKU_Produto    Categoria            Nome_Produto  \
# 0        33 2023-05-18   SKU-53822   Brinquedos           Quebra-cabeça
# 1       844 2023-03-30   SKU-97371      Esporte                  Patins
# 2       931 2023-12-28   SKU-50582  Eletrônicos                  Laptop
# 3        82 2023-11-22   SKU-97371      Esporte                  Patins
# 4       373 2023-01-14   SKU-69331         Casa  Organizador de Gavetas
#
#    Quantidade    Preco  valor_venda        Canal  mes data_mes
# 0          10   122.47      1224.70  Loja Física    5  2023-05
# 1           3   237.06       711.18  Loja Física    3  2023-03
# 2           5  4526.60     22633.00       Online   12  2023-12
# 3           8   237.06      1896.48       Online   11  2023-11
# 4           3   136.47       409.41       Online    1  2023-01

# %%
#Agrupando dados para montar um grafico, utilizando o campo que convertemos o tipo data para data[M]
#consulta abaixo, apenas para gerar o grafico, usando vendas_mensais


colunas = ['data_mes','regiao','Canal']
grouped = df.groupby(colunas)
vendas_mensais = grouped.agg(
    total_vendas = ('valor_venda', sum)
    ).reset_index()
# Out:
# C:\Users\palvesco\AppData\Local\Temp\ipykernel_4040\1299054439.py:3: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   vendas_mensais = grouped.agg(

# %%
vendas_mensais['data_mes'] = vendas_mensais['data_mes'].dt.to_timestamp()
vendas_mensais
# Out:
#       data_mes        regiao        Canal  total_vendas
# 0   2023-01-01  Centro-Oeste       Online      37773.76
# 1   2023-01-01      Nordeste  Loja Física      21218.55
# 2   2023-01-01      Nordeste       Online      99078.20
# 3   2023-01-01         Norte  Loja Física      45160.63
# 4   2023-01-01         Norte       Online      42990.78
# ..         ...           ...          ...           ...
# 114 2023-12-01         Norte       Online      60580.11
# 115 2023-12-01       Sudeste  Loja Física      13429.29
# 116 2023-12-01       Sudeste       Online       3738.81
# 117 2023-12-01           Sul  Loja Física      38870.77
# 118 2023-12-01           Sul       Online      51699.84
#
# [119 rows x 4 columns]

# %%
plt.figure(figsize=(8,4))
sns.set_palette('Pastel1')
sns.lineplot(data = vendas_mensais,
             x='data_mes',
             y= 'total_vendas',
             hue= 'Canal',
             markers= '0'
)
plt.title('Grafico de linhas')
plt.show()

# %% [markdown]
# #### Gráfico de Dispersão
# ***
# Um gráfico de dispersão é uma representação visual usada para mostrar a relação entre duas variáveis. Nele, cada ponto no gráfico indica a posição de um par de valores, com um valor no eixo X e outro no eixo Y. Esse tipo de gráfico é ideal para identificar padrões, correlações ou tendências entre as variáveis, como a ligação entre a altura e o peso de indivíduos, ou o impacto de uma variável sobre outra. É amplamente utilizado em análises estatísticas, pesquisa científica e estudos de mercado para visualizar como duas variáveis podem estar relacionadas.

# %%
df_clinicos = pd.read_csv('./datasets/dados_clientes_clusterizado.csv' , sep=';')
df_clinicos.head()
# Out:
#   sigla_estado   peso  colesterol    nome_cluster
# 0           RR  102.0         111     Risco Baixo
# 1           DF  115.0         135     Risco Baixo
# 2           AM  115.0         136     Risco Baixo
# 3           SE  130.0         158  Risco Moderado
# 4           ES  198.0         227      Risco Alto

# %%
sns.scatterplot(data = df_clinicos,
                x= 'peso',
                y= 'colesterol'
                )
# Out:
# <Axes: xlabel='peso', ylabel='colesterol'>

# %%
df_clinicos[['peso', 'colesterol']].corr()
# Out:
#                 peso  colesterol
# peso        1.000000    0.987067
# colesterol  0.987067    1.000000

# %%
#usando a clusterização do grafico para agrupar dados
plt.figure(figsize=(10,6))
sns.scatterplot(data=df_clinicos,
                x='peso',
                y='colesterol',
                hue='nome_cluster',
                palette={
                    'Risco Baixo': 'green',
                    'Risco Moderado': 'orange',
                    'Risco Alto' : 'red'
               }
             )
plt.legend(title="gráfico de cluester", loc='center right', facecolor = 'white')
plt.show()

# %% [markdown]
# #### Gráfico de Histograma
# ***
# Um histograma é uma representação visual que ilustra a distribuição de um conjuento de dados, destacando a frequência de ocorrência em diferentes intervalos. Ele exibe a contagem de dados dentro de intervalos específicos, facilitando a visualização da dispersão e da concentração dos dados.
#
# No gráfico, as "barras" representam os invervalos, ou "bins", com a altura de cada barra indicando a quantidade de dados que caem dentro daquele intervalo. A largura das barras corresponde ao tamanho dos invervalos. O histograma permite a rápida identificação de padrões, como picos e lacunas, e ajuda a compreender a forma geral da distribuição dos dados. É amplamente utilizado em análises exploratórias para avaliar a distribuição e a variabilidade dos dados.

# %%
plt.figure(figsize=(10,6))
sns.histplot(data = df_clinicos, 
             x='peso',
             bins = 35,
             hue= 'nome_cluster')
# Out:
# <Axes: xlabel='peso', ylabel='Count'>

# %% [markdown]
# #### Gráfico Boxplot
# ***
# Um boxplot é uma representação visual que resume a distribuição de um conjunto de dados, destacando seus principais estatísticos. Ele exibe a mediana, os quartis e os valores extremos, permitindo uma rápida identificação de assimetrias, dispersão e possíveis outliers.
#
# No gráfico, a "caixa" central mostra a distribuição dos 50% do meio dos dados, com a linha dentro da caixa representando a mediana. As "linhas" se estendem até os valores mínimos e máximos, enquanto pontos fora dessas linhas indicam outliers. O boxplot é amplamente utilizado em análises exploratórias de dados para comparar distribuições entre diferentes grupos ou conjuntos de dados.

# %%
sns.boxenplot(data= df_clinicos,
              x= 'peso')
# Out:
# <Axes: xlabel='peso'>

# %%
sns.boxenplot(data= df_clinicos,
              x= 'peso',
              y= 'nome_cluster',
              orient= 'h',
              hue= 'nome_cluster',
              palette={
                    'Risco Baixo': 'green',
                    'Risco Moderado': 'orange',
                    'Risco Alto' : 'red'
               }
         )
# Out:
# <Axes: xlabel='peso', ylabel='nome_cluster'>
